# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")
os.environ['OPENAI_API_KEY']  = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# Indexの構築
documents = SimpleDirectoryReader('./data/text').load_data()
index = VectorStoreIndex.from_documents(documents)

# Chat Engineの作成
llm = OpenAI(model=MODEL_NAME)
chat_engine = index.as_chat_engine(llm=llm)

# チャットの開始
while(True):
    message = input("メッセージを入力:")
    if message.strip()=="":
        break
    display(f"質問:{message}")

    # 質問（以下にソースコードを記述）
    response = chat_engine.stream_chat(message)

    # 回答を表示（以下にソースコードを記述）
    for token in response.response_gen:
        print(token, end="")
    

print("\n---ご利用ありがとうございました！---")
# Out:
# '質問:始業時間は何時ですか？'
# 始業時間は7時から10時の間で自由に選べます。
# '質問:じゃあ終業時間は？'
# 終業時間は午後6時ですが、フレックスタイム制度を利用する場合は、終業の時間を15時から19時の間で自由に選ぶことができます。
# '質問:残業時間に関しての規則はありますか？'
# 残業に関しては、通常の勤務時間を超えて働く場合は「残業」となり、事前に上司の承認を得る必要があります。また、残業が発生した場合には、法令に基づいて適切な割増賃金が支払われます。
# ---ご利用ありがとうございました！---
