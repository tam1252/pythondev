# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_6411ef453e7e42378591ed2143818420',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを活用する際のポイントは以下の通りです：\n\n1. **明確な目的設定**: 何を達成したいのかを明確にすることが重要です。情報収集、文書作成、翻訳、対話の生成など、使用目的によってアプローチが変わります。\n\n2. **文脈を考慮する**: 言語モデルは入力された文脈に依存します。質問やリクエストをする際には、具体的で詳細な情報を提供することで、より正確な回答を得ることができます。\n\n3. **フィードバックの活用**: 得られた結果に対してフィードバックを行うことで、モデルの応答を改善することが可能です。特に、繰り返し問合せることで質の高い回答を引き出せることがあります。\n\n4. **制約を認識する**: 言語モデルは完璧ではなく、時には不正確な情報を生成することがあります。結果を鵜呑みにせず、重要な情報については他の情報源と照合することが大切です。\n\n5. **倫理的配慮**: 出力内容が適切であるか、他者の権利を侵害しないかを考える必要があります。有害な内容や偏見を助長しないように注意しましょう。\n\n6. **データの扱い**: プライバシーや機密情報を含まないよう注意し、扱うデータが法律や規範に従っていることを確認しましょう。\n\n7. **多様な利用法**: 言語モデルは、単なる情報の提供だけでなく、創造的な文章の生成、アイデアのブレインストーミング、プログラミング支援など、多岐にわたる利用が可能です。\n\nこれらのポイントを考慮しながら、言語モデルを活用することで、より効果的な結果を得ることができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776033338,
#  'id': 'chatcmpl-DTxgwRwNF8VRHu5btuetpaJXBhaO0',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_a5086b7b9a',
#  'usage': CompletionUsage(completion_tokens=472, prompt_tokens=18, total_tokens=490, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを活用する際のポイントは以下の通りです：
#
# 1. **明確な目的設定**: 何を達成したいのかを明確にすることが重要です。情報収集、文書作成、翻訳、対話の生成など、使用目的によってアプローチが変わります。
#
# 2. **文脈を考慮する**: 言語モデルは入力された文脈に依存します。質問やリクエストをする際には、具体的で詳細な情報を提供することで、より正確な回答を得ることができます。
#
# 3. **フィードバックの活用**: 得られた結果に対してフィードバックを行うことで、モデルの応答を改善することが可能です。特に、繰り返し問合せることで質の高い回答を引き出せることがあります。
#
# 4. **制約を認識する**: 言語モデルは完璧ではなく、時には不正確な情報を生成することがあります。結果を鵜呑みにせず、重要な情報については他の情報源と照合することが大切です。
#
# 5. **倫理的配慮**: 出力内容が適切であるか、他者の権利を侵害しないかを考える必要があります。有害な内容や偏見を助長しないように注意しましょう。
#
# 6. **データの扱い**: プライバシーや機密情報を含まないよう注意し、扱うデータが法律や規範に従っていることを確認しましょう。
#
# 7. **多様な利用法**: 言語モデルは、単なる情報の提供だけでなく、創造的な文章の生成、アイデアのブレインストーミング、プログラミング支援など、多岐にわたる利用が可能です。
#
# これらのポイントを考慮しながら、言語モデルを活用することで、より効果的な結果を得ることができるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略はいくつかの重要なステップから成り立っています。以下に、成功を収めるための戦略を示します。
#
# ### 1. 市場調査
# - **ターゲットオーディエンスの特定**: 製品の主要なターゲット層を明確にし、どのようなニーズや欲求を満たすかを理解します。
# - **競合分析**: 同じ市場で競合する製品を分析し、差別化ポイントを見つけます。
#
# ### 2. 製品のポジショニング
# - **ユニークセリングプロポジション (USP)**: 製品の独自性を強調し、他社製品とは異なる理由を明確にします。
# - **ブランドメッセージ**: 明確なブランドメッセージを定義し、顧客に対する一貫したコミュニケーションを心掛けます。
#
# ### 3. プレローンチキャンペーン
# - **ティーザー広告**: 製品の情報を徐々に公開し、期待感を醸成するためのキャンペーンを展開します。
# - **ソーシャルメディア活用**: SNSでのファン生成や興味を引くためのコンテンツを作成し、エンゲージメントを高めます。
#
# ### 4. 発売日計画
# - **イベントの開催**: 発売日にはオフラインまたはオンラインのイベントを開催し、新製品を実際に体験できる機会を提供します。
# - **インフルエンサーとのコラボレーション**: 影響力のあるインフルエンサーに製品を紹介してもらい、信頼性を高めます。
#
# ### 5. 販売チャネルの整備
# - **オンラインとオフラインの統合**: ECサイトや実店舗での販売戦略を同時に考慮し、顧客にとっての利便性を高めます。
# - **特典やキャンペーンの実施**: 発売初期に割引や特典を提供し、購入を促進します。
#
# ### 6. フィードバックとデータ分析
# - **顧客の反応のモニタリング**: 発売後の顧客の反応や売上データを分析し、戦略の改善に役立てます。
# - **アフターサービスと顧客サポート**: 購入後のフォローを重視し、顧客満足度を高めるためのサポート体制を整えます。
#
# ### 7. 持続的なマーケティング
# - **継続的なプロモーション**: 発売後もSNSや広告キャンペーンを通じて製品をプロモーションし続け、ブランドの認知度を高めます。
# - **リピート顧客の獲得**: 購入者へのフォローアップやロイヤルティプログラムを展開し、再購入を促進します。
#
# これらの戦略を総合的に活用することで、新製品の市場での成功を高めることができます。成功を収めるためには、一貫したメッセージングと顧客のニーズに基づいたアプローチが重要です。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本の魅力は、多岐にわたります。以下にいくつかのポイントを紹介します。
#
# 1. **豊かな文化と歴史**: 日本は、古代から続く伝統と現代的な影響が融合した文化を持っています。寺院、神社、城跡など、歴史的な建造物が多く存在し、四季折々の祭りや伝統芸能（例えば、
# --------------------
# 日本は多様な魅力にあふれた国です。以下に代表的なポイントを紹介します。
#
# 1. **豊かな自然**:
#    - 四季折々の風景があり、桜の季節や紅葉の時期には美しい自然が見られます。北海道の大自然や、温泉地も多く存在します。
#
# 2. **文化と伝統**:
#    - 日本の伝統文化は深く
# --------------------
# もちろんです！日本には多彩な魅力がありますので、いくつか紹介しますね。
#
# ### 1. 美しい自然
# 日本は四季がはっきりしており、春の桜、夏の滝や海、秋の紅葉、冬の雪景色と、多様な自然の風景が楽しめます。特に、富士山や北アルプスなどの山々は、アウトドア・アク

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な魅力を持つ国です。以下は日本の魅力のいくつかです。
#
# ### 1. 文化と伝統
# 日本は長い歴史を持つ国で、伝統的な文化が今も大切にされています。茶道、書道、着物、浮世絵など、日本独自の文化が多くの人を魅了しています。
#
# ### 2. 自然の
# --------------------
# もちろんです！日本は多様な魅力を持つ国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 自然の美
# 日本には美しい自然景観が広がっています。四季折々の景色が楽しめるのが特徴で、春の桜、夏の緑、秋の紅葉、冬の雪景色は特に印象的です。特に、富士山や
# --------------------
# 日本は多様な魅力を持つ国で、訪れる人々を惹きつけてやみません。以下は日本の魅力のいくつかです。
#
# ### 1. 文化と歴史
# 日本は豊かな歴史を持つ国で、古代の神社や寺、城、伝統的な文化が数多く残っています。京都の清水寺や奈良の東大寺、広島

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、お久しぶり！最近どうしてた？
# --------------------
# B:こんにちは、Aさん！今日はどうしたの？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に利用するためのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目的を設定する**: 何を達成したいのか、具体的な目標を定めることで、使用する際の方向性が明確になります。
#
# 2. **プロンプトの工夫**: モデルに与える入力（プロンプト）の質が結果に大きく影響します。具体的かつ詳細なプロンプトを考えることで、期待する応答を得やすくなります。
#
# 3. **段階的なコミュニケーション**: 複雑な質問や要求は、段階的に行うことでモデルが理解しやすくなります。まず基本的な情報を引き出し、その後に詳細を追加していく形が効果的です。
#
# 4. **フィードバックを利用する**: モデルから得られる応答に対して、フィードバックを与えることで、次回の応答が改善される可能性があります。例えば、応答が不十分な場合は、その点を指摘して再度質問することが重要です。
#
# 5. **文脈を保持する**: 前の対話やトピックに関連する情報をモデルが持つことで、より一貫性のある応答が得られますが、文脈を与える際には注意が必要です。適切にコンテキストを設定しましょう。
#
# 6. **限界を理解する**: 言語モデルは完全ではなく、誤った情報や非現実的な提案をすることがあります。そのため、結果を鵜呑みにせず、批判的に考えることが重要です。
#
# 7. **倫理的な配慮**: 誤情報の拡散や差別的な表現の排除など、倫理的な側面にも注意を払う必要があります。適切な利用を心がけましょう。
#
# これらのポイントを意識しながら言語モデルを活用することで、より有益な情報を引き出すことができます。
