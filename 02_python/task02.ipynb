# %%
price = int(input("商品の税抜き価格を入力してください: "))
tax_included_price = int(price * 1.1)

if tax_included_price >= 2000:
    print("送料は無料です。")
    print(f"送料込み税込価格は {tax_included_price} 円です。")
else:
    print("送料は350円です。")
    print(f"送料込み税込価格は {tax_included_price + 350} 円です。")
